# %% [markdown]
# Practical No.:2
# Roll no.:13221

# %%
import numpy as np

# %%
x= np.array([[3,2,1,0],[7,6,5,4],[11,10,9,8]])

# %%
print(x)
# Out:
# [[ 3  2  1  0]
#  [ 7  6  5  4]
#  [11 10  9  8]]

# %%
print("value at [0][0] and [0][1] : ",x[0:1,0:2])
# Out:
# value at [0][0] and [0][1] :  [[3 2]]

# %%
print("value at[0][1] , [0][2] , [0][3] :",x[0:1,1:4])
# Out:
# value at[0][1] , [0][2] , [0][3] : [[2 1 0]]

# %%
print("value at[1][0] :",x[1:2, 0:1])
# Out:
# value at[1][0] : [[7]]

# %%
print("value at[1][1],[1,2],[1,3] :",x[1:2,1:4])
# Out:
# value at[1][1],[1,2],[1,3] : [[6 5 4]]

# %%
print(x[1:3,1:4])
# Out:
# [[ 6  5  4]
#  [10  9  8]]

# %%
y=np.array([[12 ,45 ,33 ,8], [27 ,59 ,41 ,19],[36 ,22 ,54 ,48],[6 ,31 ,17 ,50]])
