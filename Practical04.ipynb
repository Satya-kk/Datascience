# %% [markdown]
# Assignment No : 02

# %% [markdown]
# Roll no. : 13221

# %%
import pandas as pd

# %%
df=pd.read_csv("C:/Users/admin/OneDrive/Desktop/Student_performance.csv")

# %%
df
# Out:
#     Math_score  Reading_score  Writing_score  Placement_score  Club_Join_Date  \
# 0         78.0           81.0           67.0             95.0          2020.0
# 1         65.0           77.0           65.0             90.0          2020.0
# 2         78.0           86.0           60.0             79.0          2020.0
# 3         10.0           80.0           66.0             20.0          2021.0
# 4         71.0           30.0           67.0             96.0             5.0
# 5         68.0           92.0           73.0            100.0          2020.0
# 6         70.0           81.0           80.0             84.0          2020.0
# 7         79.0           79.0           65.0             78.0          2021.0
# 8         77.0           87.0            5.0             77.0          2020.0
# 9         73.0           92.0           68.0             82.0          2021.0
# 10        75.0           90.0           80.0             79.0          2021.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Math_score             44 non-null     float64
#  1   Reading_score          45 non-null     float64
#  2   Writing_score          45 non-null     float64
#  3   Placement_score        46 non-null     float64
#  4   Club_Join_Date         45 non-null     float64
#  5   Placement_Offer_count  50 non-null     int64
# dtypes: float64(5), int64(1)
# memory usage: 2.5 KB

# %%
df.isnull().sum()
# Out:
# Math_score               6
# Reading_score            5
# Writing_score            5
# Placement_score          4
# Club_Join_Date           5
# Placement_Offer_count    0
# dtype: int64

# %%
df.describe()
# Out:
#        Math_score  Reading_score  Writing_score  Placement_score  \
# count   44.000000      45.000000      45.000000        46.000000
# mean    68.272727      79.488889      67.600000        83.217391
# std     14.548018      18.551675      15.485184        21.562223
# min      5.000000       2.000000       5.000000         1.000000
# 25%     66.750000      77.000000      65.000000        80.250000
# 50%     70.000000      82.000000      68.000000        89.500000
# 75%     75.000000      89.000000      76.000000        95.000000
# max     90.000000      95.000000      95.000000       100.000000
#
#        Club_Join_Date  Placement_Offer_count
# count       45.000000              50.000000
# mean      1930.177778               2.880000
# std        419.342412               1.364865
# min          5.000000               2.000000
# 25%       2019.000000               2.000000
# 50%       2020.000000               3.000000
# 75%       2020.000000               3.000000
# ...

# %%
x=df.Math_score.mean()

# %%
df.Math_score.fillna(x,inplace=True)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_30812\3906181918.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Math_score.fillna(x,inplace=True)

# %%
df
# Out:
#     Math_score  Reading_score  Writing_score  Placement_score  Club_Join_Date  \
# 0    78.000000           81.0           67.0             95.0          2020.0
# 1    65.000000           77.0           65.0             90.0          2020.0
# 2    78.000000           86.0           60.0             79.0          2020.0
# 3    10.000000           80.0           66.0             20.0          2021.0
# 4    71.000000           30.0           67.0             96.0             5.0
# 5    68.000000           92.0           73.0            100.0          2020.0
# 6    70.000000           81.0           80.0             84.0          2020.0
# 7    79.000000           79.0           65.0             78.0          2021.0
# 8    77.000000           87.0            5.0             77.0          2020.0
# 9    73.000000           92.0           68.0             82.0          2021.0
# 10   75.000000           90.0           80.0             79.0          2021.0
# ...

# %%
y=df.Reading_score.mean()

# %%
df.Reading_score.fillna(y,inplace=True)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_30812\325959419.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Reading_score.fillna(y,inplace=True)

# %%
df
# Out:
#     Math_score  Reading_score  Writing_score  Placement_score  Club_Join_Date  \
# 0    78.000000      81.000000           67.0             95.0          2020.0
# 1    65.000000      77.000000           65.0             90.0          2020.0
# 2    78.000000      86.000000           60.0             79.0          2020.0
# 3    10.000000      80.000000           66.0             20.0          2021.0
# 4    71.000000      30.000000           67.0             96.0             5.0
# 5    68.000000      92.000000           73.0            100.0          2020.0
# 6    70.000000      81.000000           80.0             84.0          2020.0
# 7    79.000000      79.000000           65.0             78.0          2021.0
# 8    77.000000      87.000000            5.0             77.0          2020.0
# 9    73.000000      92.000000           68.0             82.0          2021.0
# 10   75.000000      90.000000           80.0             79.0          2021.0
# ...

# %%
y=df.Writing_score.mean()

# %%
df.Writing_score.fillna(y,inplace=True)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_30812\2836506674.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Writing_score.fillna(y,inplace=True)

# %%
df
# Out:
#     Math_score  Reading_score  Writing_score  Placement_score  Club_Join_Date  \
# 0    78.000000      81.000000           67.0             95.0          2020.0
# 1    65.000000      77.000000           65.0             90.0          2020.0
# 2    78.000000      86.000000           60.0             79.0          2020.0
# 3    10.000000      80.000000           66.0             20.0          2021.0
# 4    71.000000      30.000000           67.0             96.0             5.0
# 5    68.000000      92.000000           73.0            100.0          2020.0
# 6    70.000000      81.000000           80.0             84.0          2020.0
# 7    79.000000      79.000000           65.0             78.0          2021.0
# 8    77.000000      87.000000            5.0             77.0          2020.0
# 9    73.000000      92.000000           68.0             82.0          2021.0
# 10   75.000000      90.000000           80.0             79.0          2021.0
# ...

# %%
df
# Out:
#     Math_score  Reading_score  Writing_score  Placement_score  Club_Join_Date  \
# 0    78.000000      81.000000           67.0             95.0     2020.000000
# 1    65.000000      77.000000           65.0             90.0     2020.000000
# 2    78.000000      86.000000           60.0             79.0     2020.000000
# 3    10.000000      80.000000           66.0             20.0     2021.000000
# 4    71.000000      30.000000           67.0             96.0        5.000000
# 5    68.000000      92.000000           73.0            100.0     2020.000000
# 6    70.000000      81.000000           80.0             84.0     2020.000000
# 7    79.000000      79.000000           65.0             78.0     2021.000000
# 8    77.000000      87.000000            5.0             77.0     2020.000000
# 9    73.000000      92.000000           68.0             82.0     2021.000000
# 10   75.000000      90.000000           80.0             79.0     2021.000000
# ...

# %%
import numpy as np

# %%
df['Club_Join_Date'] = df['Club_Join_Date'].replace(1930.177778, np.nan)

# %%
df
# Out:
#     Math_score  Reading_score  Writing_score  Placement_score  Club_Join_Date  \
# 0    78.000000      81.000000           67.0             95.0     2020.000000
# 1    65.000000      77.000000           65.0             90.0     2020.000000
# 2    78.000000      86.000000           60.0             79.0     2020.000000
# 3    10.000000      80.000000           66.0             20.0     2021.000000
# 4    71.000000      30.000000           67.0             96.0        5.000000
# 5    68.000000      92.000000           73.0            100.0     2020.000000
# 6    70.000000      81.000000           80.0             84.0     2020.000000
# 7    79.000000      79.000000           65.0             78.0     2021.000000
# 8    77.000000      87.000000            5.0             77.0     2020.000000
# 9    73.000000      92.000000           68.0             82.0     2021.000000
# 10   75.000000      90.000000           80.0             79.0     2021.000000
# ...

# %%
df['Club_Join_Date'] = df['Club_Join_Date'].replace(1930.177778, np.nan,inplace=True)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_30812\8621128.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Club_Join_Date'] = df['Club_Join_Date'].replace(1930.177778, np.nan,inplace=True)

# %%
df
# Out:
#     Math_score  Reading_score  Writing_score  Placement_score Club_Join_Date  \
# 0    78.000000      81.000000           67.0             95.0           None
# 1    65.000000      77.000000           65.0             90.0           None
# 2    78.000000      86.000000           60.0             79.0           None
# 3    10.000000      80.000000           66.0             20.0           None
# 4    71.000000      30.000000           67.0             96.0           None
# 5    68.000000      92.000000           73.0            100.0           None
# 6    70.000000      81.000000           80.0             84.0           None
# 7    79.000000      79.000000           65.0             78.0           None
# 8    77.000000      87.000000            5.0             77.0           None
# 9    73.000000      92.000000           68.0             82.0           None
# 10   75.000000      90.000000           80.0             79.0           None
# ...

# %%
df['Club_Join_Date'].fillna(2020, inplace=True)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_30812\4027227670.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Club_Join_Date'].fillna(2020, inplace=True)
# C:\Users\admin\AppData\Local\Temp\ipykernel_30812\4027227670.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# ...

# %%
df
# Out:
#     Math_score  Reading_score  Writing_score  Placement_score  Club_Join_Date  \
# 0    78.000000      81.000000           67.0             95.0            2020
# 1    65.000000      77.000000           65.0             90.0            2020
# 2    78.000000      86.000000           60.0             79.0            2020
# 3    10.000000      80.000000           66.0             20.0            2020
# 4    71.000000      30.000000           67.0             96.0            2020
# 5    68.000000      92.000000           73.0            100.0            2020
# 6    70.000000      81.000000           80.0             84.0            2020
# 7    79.000000      79.000000           65.0             78.0            2020
# 8    77.000000      87.000000            5.0             77.0            2020
# 9    73.000000      92.000000           68.0             82.0            2020
# 10   75.000000      90.000000           80.0             79.0            2020
# ...

# %%
df.isnull().sum().sum()
# Out:
# np.int64(4)

# %%
df.Placement_score.fillna(222, inplace=True)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_30812\1599329659.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Placement_score.fillna(222, inplace=True)

# %%
df
# Out:
#     Math_score  Reading_score  Writing_score  Placement_score  Club_Join_Date  \
# 0    78.000000      81.000000           67.0             95.0            2020
# 1    65.000000      77.000000           65.0             90.0            2020
# 2    78.000000      86.000000           60.0             79.0            2020
# 3    10.000000      80.000000           66.0             20.0            2020
# 4    71.000000      30.000000           67.0             96.0            2020
# 5    68.000000      92.000000           73.0            100.0            2020
# 6    70.000000      81.000000           80.0             84.0            2020
# 7    79.000000      79.000000           65.0             78.0            2020
# 8    77.000000      87.000000            5.0             77.0            2020
# 9    73.000000      92.000000           68.0             82.0            2020
# 10   75.000000      90.000000           80.0             79.0            2020
# ...

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['Math_score', 'Reading_score', 'Writing_score', 'Placement_score',
#        'Club_Join_Date', 'Placement_Offer_count'],
#       dtype='object')

# %%
col = ['Math_score', 'Reading_score', 'Writing_score', 'Placement_score',
       'Club_Join_Date', 'Placement_Offer_count']

# %%
df.boxplot(col)
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt

# %%
plt.show()

# %%
col1 =['Math_score', 'Reading_score', 'Writing_score', 'Placement_score']

# %%
df.boxplot(col1)
# Out:
# <Axes: >

# %%
plt.show()

# %%
plt.scatterplot(Placement_score, Placement_Offer_count)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[88], line 1
# ----> 1 plt.scatterplot(Placement_score, Placement_Offer_count)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'scatterplot'

# %%
fig, ax = plt.subplots(figsize = (18,10))

# %%
ax.scatter(df['Placement_score'], df['Placement_Offer_count'])

# %%
plt.show()

# %%
q1 = np.percentile(df.Placement_Offer_count , 25)

# %%
q1
# Out:
# np.float64(2.0)

# %%
df.describe()
# Out:
#        Math_score  Reading_score  Writing_score  Placement_score  \
# count   50.000000      50.000000       50.00000          50.0000
# mean    68.272727      79.488889       67.60000          94.3200
# std     13.628247      17.579699       14.67387          43.2838
# min      5.000000       2.000000        5.00000           1.0000
# 25%     68.000000      78.250000       65.00000          81.0000
# 50%     69.000000      80.500000       67.60000          91.0000
# 75%     74.000000      88.000000       75.00000          96.0000
# max     90.000000      95.000000       95.00000         222.0000
#
#        Club_Join_Date  Placement_Offer_count
# count            50.0              50.000000
# mean           2020.0               2.880000
# std               0.0               1.364865
# min            2020.0               2.000000
# 25%            2020.0               2.000000
# 50%            2020.0               3.000000
# 75%            2020.0               3.000000
# ...

# %%
q3 = np.percentile(df.Placement_Offer_count , 75)

# %%
IQR = q3 - q1

# %%
IQR
# Out:
# np.float64(1.0)

# %%
upper_bod = q3 + 1.5*IQR

# %%
upper_bod
# Out:
# np.float64(4.5)

# %%
lower_bod= q1 - 1.5*IQR

# %%
lower_bod
# Out:
# np.float64(0.5)

# %%
from scipy import stats

# %%
s = np.abs(stats.sscore(df['Placement_Offer_count']))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[103], line 1
# ----> 1 s = np.abs(stats.sscore(df['Placement_Offer_count']))
#
# AttributeError: module 'scipy.stats' has no attribute 'sscore'

# %%
s = np.abs(stats.zscore(df['Placement_Offer_count']))

# %%
s
# Out:
# array([0.08881339, 0.08881339, 0.65129817, 0.08881339, 0.08881339,
#        0.08881339, 0.65129817, 0.65129817, 0.65129817, 0.65129817,
#        0.65129817, 0.65129817, 0.65129817, 5.26959429, 0.65129817,
#        0.65129817, 0.65129817, 0.08881339, 0.08881339, 0.08881339,
#        0.08881339, 0.08881339, 0.08881339, 3.78937118, 0.65129817,
#        0.08881339, 0.08881339, 0.08881339, 0.65129817, 0.08881339,
#        0.08881339, 0.08881339, 0.08881339, 0.08881339, 0.08881339,
#        0.65129817, 0.08881339, 0.65129817, 0.08881339, 0.08881339,
#        0.65129817, 0.08881339, 0.08881339, 0.08881339, 0.08881339,
#        0.08881339, 0.65129817, 0.08881339, 0.08881339, 0.65129817])
